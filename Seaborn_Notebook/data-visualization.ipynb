# %% [markdown]
# <a href="https://www.kaggle.com/code/bhavkaur/data-visualization?scriptVersionId=133253501" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

print("Setup Complete")
# Out:
# /kaggle/input/data-for-datavis/fifa.csv
# /kaggle/input/data-for-datavis/ign_scores.csv
# /kaggle/input/data-for-datavis/spotify.csv
# /kaggle/input/data-for-datavis/flight_delays.csv
# /kaggle/input/data-for-datavis/iris_setosa.csv
# /kaggle/input/data-for-datavis/insurance.csv
# /kaggle/input/data-for-datavis/cancer.csv
# /kaggle/input/data-for-datavis/cancer_b.csv
# /kaggle/input/data-for-datavis/cancer_m.csv
# /kaggle/input/data-for-datavis/iris_virginica.csv
# /kaggle/input/data-for-datavis/iris.csv
# /kaggle/input/data-for-datavis/iris_versicolor.csv
# /kaggle/input/data-for-datavis/candy.csv
# /kaggle/input/data-for-datavis/museum_visitors.csv
# Setup Complete

# %% [markdown]
# # **HOW TO CHOOSE PLOT TYPE?**
# **Trends** - A trend is defined as a pattern of change.
#  - sns.lineplot - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# **Relationship** - There are many different chart types that you can use to understand relationships between variables in your data.
#  - sns.barplot - Bar charts are useful for comparing quantities corresponding to different groups.
#  - sns.heatmap - Heatmaps can be used to find color-coded patterns in tables of numbers.
#  - sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#  - sns.regplot - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#  - sns.lmplot - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#  - sns.swarmplot - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
#
# **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
# - sns.histplot - Histograms show the distribution of a single numerical variable.
# - sns.kdeplot - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
# - sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %%
# Give file path
fifa_filepath = "/kaggle/input/data-for-datavis/fifa.csv"
print('Done')
# Out:
# Done

# %%
#Read data from file
data_fifa = pd.read_csv(fifa_filepath)
print('Done')
# Out:
# Done

# %%
data_fifa.head()
# Out:
#          Date   ARG  BRA   ESP   FRA  GER  ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# ## **LINE PLOT**

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=data_fifa)
plt.show()

# %% [markdown]
# ## **BAR PLOT**

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=data_fifa.index, y=data_fifa['BRA'])
# Out:
# <Axes: ylabel='BRA'>

# %% [markdown]
# ## **HEATMAP**

# %%
fl_filepath ="/kaggle/input/data-for-datavis/flight_delays.csv"
data_fl = pd.read_csv(fl_filepath)
print('Done')
# Out:
# Done

# %%
plt.figure(figsize=(14,7))

sns.heatmap(data=data_fl, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **SCATTER PLOTS**

# %%
in_filepath = "/kaggle/input/data-for-datavis/insurance.csv"
data_in = pd.read_csv(in_filepath)
print('Done')
# Out:
# Done

# %%
sns.scatterplot(x=data_in['bmi'], y=data_in['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## **COLOR CODEDE SCATTER PLOT**

# %%
sns.scatterplot(x=data_in['bmi'], y=data_in['charges'], hue=data_in['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## **REG PLOT**

# %%
sns.regplot(x=data_in['bmi'], y=data_in['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## **To Add Two Regression Lines**

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=data_in, palette=['green','red'], legend='full')

# %% [markdown]
# ## **SWARMPLOT**

# %%
sns.swarmplot(x=data_in['smoker'],y=data_in['charges'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## **HISTOGRAMS**

# %%
iris_filepath = "/kaggle/input/data-for-datavis/iris.csv"
iris_data = pd.read_csv(iris_filepath,index_col="Id")
print('Done')
iris_data.head()
# Out:
# Done
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
sns.histplot(iris_data['Petal Length (cm)'], color='steelblue')
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ## **DENSITY PLOTS**

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], fill=True, color="red")
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ## **2D KDE PLOTS**

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde",fill=True)

# %%
candy_filepath="/kaggle/input/data-for-datavis/candy.csv"
candy_data=pd.read_csv(candy_filepath)
print('done')
candy_data.head()
# Out:
# done
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# ## **VIOLIN PLOT**

# %%
iris_data.columns
# Out:
# Index(['Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)',
#        'Petal Width (cm)', 'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=iris_data);

# %% [markdown]
# ## **DISPLOT**

# %%
sns.displot(data=candy_data, x="sugarpercent", y="pricepercent")

# %%
sns.displot(data=candy_data, x="sugarpercent", kde=True)

# %% [markdown]
# ## **BOXPLOT**

# %%
sns.boxplot(x=candy_data["sugarpercent"])
# Out:
# <Axes: xlabel='sugarpercent'>

# %% [markdown]
# ## **JOINTPLOT**

# %%
sns.jointplot(data=candy_data, x="sugarpercent", y="pricepercent", height=5, ratio=2, marginal_ticks=True)

# %% [markdown]
# ## **STRIP PLOT**

# %%
sns.stripplot(data=iris_data, x="Sepal Length (cm)", y="Petal Length (cm)")
# Out:
# <Axes: xlabel='Sepal Length (cm)', ylabel='Petal Length (cm)'>
